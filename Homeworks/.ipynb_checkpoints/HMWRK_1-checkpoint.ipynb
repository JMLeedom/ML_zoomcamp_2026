# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.6'

# %%
# !wget https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/car_fuel_efficiency_2026.csv
# Out:
# --2026-09-24 13:25:50--  https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/car_fuel_efficiency_2026.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 635180 (620K) [text/plain]
# Saving to: ‘car_fuel_efficiency_2026.csv’
#
# car_fuel_efficiency 100%[===================>] 620.29K  --.-KB/s    in 0.004s
#
# 2026-09-24 13:25:50 (154 MB/s) - ‘car_fuel_efficiency_2026.csv’ saved [635180/635180]

# %%
url = "https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/car_fuel_efficiency_2026.csv"
df=pd.read_csv(url)
df.head()
# Out:
#    model_year  origin fuel_type         drivetrain  num_doors  \
# 0        2006  Europe  Gasoline  Front-wheel drive          4
# 1        2008  Europe    Diesel  Front-wheel drive          4
# 2        1996    Asia  Gasoline  Front-wheel drive          5
# 3        1989  Europe  Gasoline  Front-wheel drive          4
# 4        1994     USA    Diesel  Front-wheel drive          3
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                 2180              6       243.0            3870
# 1                 2390              6       272.0            4210
# 2                 2320              6       267.0            4240
# 3                 2130              6       258.0            4490
# 4                 2580              7       304.0            4510
#
#    acceleration  fuel_efficiency_mpg
# 0           NaN                 31.9
# 1           NaN                 31.3
# 2          17.3                 27.5
# 3          18.7                 28.5
# ...

# %%
len(df)
# Out:
# 10000

# %%
df.shape[0]
# Out:
# 10000

# %%
df.fuel_type.describe()
# Out:
# count        10000
# unique           3
# top       Gasoline
# freq          6913
# Name: fuel_type, dtype: object

# %%
df["fuel_type"].nunique()
# Out:
# 3

# %%
df.isnull().sum()
# Out:
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors                0
# engine_displacement      0
# num_cylinders            0
# horsepower             877
# vehicle_weight           0
# acceleration           264
# fuel_efficiency_mpg      0
# dtype: int64

# %%
df[
    df["origin"] == "Asia"
]["fuel_efficiency_mpg"].max()
# Out:
# np.float64(41.2)

# %%
df["horsepower"].median()
# Out:
# np.float64(254.0)

# %%
df["horsepower"].value_counts().head(1)
# Out:
# horsepower
# 252.0    174
# Name: count, dtype: int64

# %%
most_common = df["horsepower"].mode().iloc[0]
df["horsepower"] = df["horsepower"].fillna(most_common)

# %%
df["horsepower"].median()
# Out:
# np.float64(252.0)

# %%
X = df[
    df["origin"] == "Asia"
][["vehicle_weight","model_year"]].head(n=7).values

# %%
XTX = X.T @ X

# %%
XTX = X.T @ X
XTX_inv = np.linalg.inv(XTX)

# %%
y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])

# %%
w = (XTX_inv @ X.T) @ y

# %%
w.sum()
# Out:
# np.float64(0.36919696904927746)
